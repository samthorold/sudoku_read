# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# %%
from IPython.display import Image

# %%
import read_sudoku as rs

# %%
data = Path("../sudoku_dataset/original/")

# %%
# !ls ../sudoku_dataset/original/
# Out:
# image1000.original.jpg  image1032.original.jpg  image1064.original.jpg
# image1001.original.jpg  image1033.original.jpg  image1065.original.jpg
# image1002.original.jpg  image1034.original.jpg  image1066.original.jpg
# image1003.original.jpg  image1035.original.jpg  image1067.original.jpg
# image1004.original.jpg  image1036.original.jpg  image1068.original.jpg
# image1005.original.jpg  image1037.original.jpg  image1069.original.jpg
# image1006.original.jpg  image1038.original.jpg  image1070.original.jpg
# image1007.original.jpg  image1039.original.jpg  image1071.original.jpg
# image1008.original.jpg  image1040.original.jpg  image1072.original.jpg
# image1009.original.jpg  image1041.original.jpg  image1073.original.jpg
# image1010.original.jpg  image1042.original.jpg  image1074.original.jpg
# image1011.original.jpg  image1043.original.jpg  image1075.original.jpg
# image1012.original.jpg  image1044.original.jpg  image1076.original.jpg
# ...

# %%
Image(data / "image1001.original.jpg")
